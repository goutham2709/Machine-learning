# %%
import pandas as pd
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

df = pd.read_csv('Iris_dataset.txt', sep = ',', header = None)
#print(df)

# %%
replace_names = {'Iris-setosa': '1', 'Iris-virginica': '3', 'Iris-versicolor':'2'}
df.replace(replace_names, regex = True, inplace = True)
# df.head
df.columns = ('sepal length', 'sepal width', 'petal length', 'petal width', 'class')
# print(df)

# %%
# df[df.columns[0]]

# %%
#plot = pyplot.scatter(1, 2)
df.plot.scatter('sepal length', 'sepal width')

# %%
df.plot.scatter('sepal length', 'petal length')

# %%
df.plot.scatter('sepal length','petal width')

# %%
df.plot.scatter('sepal width', 'petal length')

# %%
df.plot.scatter('sepal width', 'petal width')

# %%
df.plot.scatter('petal length', 'petal width')

# %%
fig = plt.figure()
ax = Axes3D(fig) 
ax.scatter(df[df.columns[0]], df[df.columns[1]], df[df.columns[3]], c = 'red')
