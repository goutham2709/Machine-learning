# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
df = pd.read_csv('iriss.txt', sep = ',', header = None)
df.columns = list('ABCDE')
# data

# %%
replace_names = {'Iris-setosa':'1','Iris-virginica':'3','Iris-versicolor':'2'}
df.replace(replace_names, regex = True, inplace = True)
# df

# %%
features = df.iloc[:,0:4]
cls = df.iloc[:,4]
# features
# cls

# %%
# from pandas.plotting import scatter_matrix
# https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html
from pandas.plotting import scatter_matrix
scatter_matrix(features, alpha = 1, figsize=(12, 12))
plt.show()

# %%
# https://stackoverflow.com/questions/17071871/select-rows-from-a-dataframe-based-on-values-in-a-column-in-pandas
xone = df.loc[df['E'] == '1']
x_one = xone.iloc[:,0]
yone = df.loc[df['E'] == '1']
y_one = yone.iloc[:,1]
zone = df.loc[df['E'] == '1']
z_one = zone.iloc[:,2]
zzone = df.loc[df['E'] == '1']
zz_one = zone.iloc[:,3]

# print(zz_one)

# %%
xtwo = df.loc[df['E'] == '2']
x_two = xone.iloc[:,0]
ytwo = df.loc[df['E'] == '2']
y_two = yone.iloc[:,1]
ztwo = df.loc[df['E'] == '2']
z_two = zone.iloc[:,2]
zztwo = df.loc[df['E'] == '2']
zz_two = zone.iloc[:,3]

# print(zz_two)

# %%
xthre = df.loc[df['E'] == '2']
x_thre = xone.iloc[:,0]
ythre = df.loc[df['E'] == '2']
y_thre = yone.iloc[:,1]
zthre = df.loc[df['E'] == '2']
z_thre = zone.iloc[:,2]
zzthre = df.loc[df['E'] == '2']
zz_thre = zone.iloc[:,3]

# print(z_thre)

# %%
# a = df.iloc[:,2]
# z_two.isin(a)

# %%
# https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
# x = [x_one, x_two, x_thre]
# x = pd.concat(x)
# len(x)

# %%
# https://pythonprogramming.net/matplotlib-3d-scatterplot-tutorial/
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

x = df.iloc[:,0]
y = df.iloc[:,1]
z = df.iloc[:,2]
ax.scatter(x, y, z, c='r', marker='o')
ax.set_xlabel('Sepal Length')
ax.set_ylabel('Sepal Width')
ax.set_zlabel('Petal Length')
plt.show()

# %%
# https://stackoverflow.com/questions/14657433/correlation-matrix-in-python
a = df.iloc[:, 0].values
b = df.iloc[:, 1].values
c = df.iloc[:, 2].values
d = df.iloc[:, 3].values
corr = np.corrcoef([a, b, c, d])
print(corr)
# Out:
# [[ 1.         -0.10936925  0.87175416  0.81795363]
#  [-0.10936925  1.         -0.4205161  -0.35654409]
#  [ 0.87175416 -0.4205161   1.          0.9627571 ]
#  [ 0.81795363 -0.35654409  0.9627571   1.        ]]

# %%
# https://stackoverflow.com/questions/38913965/make-the-size-of-a-heatmap-bigger-with-seaborn
import seaborn as sns
fig, ax = plt.subplots(figsize=(12,10))
sns.heatmap(corr)
plt.show()

# %%
#parallel coordinates 
col = df.iloc[:,4]
# col
# pd.plotting.parallel_coordinates(df,col, color=('#556270', '#4ECDC4', '#C7F464'))

# %%
# https://www.kaggle.com/lalitharajesh/iris-dataset-exploratory-data-analysis
plt.figure(figsize=(15,12))
plt.subplot(2,2,1)
sns.boxplot(x=cls,y='A',data=df)
plt.subplot(2,2,2)
sns.boxplot(x=cls,y='B',data=df)
plt.subplot(2,2,3)
sns.boxplot(x=cls,y='C',data=df)
plt.subplot(2,2,4)
sns.boxplot(x=cls,y='D',data=df)
plt.show()

# LABELS

# %%
from math import *
from decimal import Decimal 

def p_root(value, root): 
    root_value = 1 / float(root) 
    return round (Decimal(value) **
             Decimal(root_value), 3) 
  
def minkowski_distance(x, y, p_value): 
    return (p_root(sum(pow(abs(a-b), p_value) 
            for a, b in zip(x, y)), p_value))

# %%
vector1 = features.iloc[::]
vector2 = [5.0000,3.5000,1.4600,0.2540] 
r = 1

print(minkowski_distance(vector1, vector2, r))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-11d208d0773a> in <module>
#       3 r = 1
#       4
# ----> 5 print(minkowski_distance(vector1, vector2, r))
#
# <ipython-input-16-28b63ceb8e60> in minkowski_distance(x, y, p_value)
#       9 def minkowski_distance(x, y, p_value):
#      10     return (p_root(sum(pow(abs(a-b), p_value)
# ---> 11             for a, b in zip(x, y)), p_value))
#
# <ipython-input-16-28b63ceb8e60> in <genexpr>(.0)
#       9 def minkowski_distance(x, y, p_value):
#      10     return (p_root(sum(pow(abs(a-b), p_value)
# ---> 11             for a, b in zip(x, y)), p_value))
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'

# %%
vector1 = features.iloc[::]
vector2 = [5.0000,3.5000,1.4600,0.2540] 
r = 2

print(minkowski_distance(vector1, vector2, r))

# %%
vector1 = features.iloc[::]
vector2 = [5.0000,3.5000,1.4600,0.2540] 
r = 100

print(minkowski_distance(vector1, vector2, r))

# %%
df.describe()
# Out:
#                 A           B           C           D
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
#https://stackoverflow.com/questions/8230638/parallel-coordinates-plot-in-matplotlib
from pandas.plotting import parallel_coordinates
parallel_coordinates(df, 'A')
plt.show()
