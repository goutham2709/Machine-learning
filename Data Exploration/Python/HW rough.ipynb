# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('Iris_dataset.txt', sep = ',', header = None)
replace_names = {'Iris-setosa': '1', 'Iris-virginica': '3', 'Iris-versicolor':'2'}
df.replace(replace_names, regex = True, inplace = True)
# df.head
df.columns = ('sepal length', 'sepal width', 'petal length', 'petal width', 'class')
# print(df)

# %%
x_one = df[df.columns[0]]
x_two = df[df.columns[1]]
# print(x)

# %%
plt.scatter(x_one, x_two, c='k', marker ='^' )

# %%
plt.scatter(x_one, x_two, c='b', marker ='^')
plt.scatter(x_one, x_three, c='g', marker ='*')
plt.scatter(x_one, x_four, c='y', marker ='.')
plt.scatter(x_two, x_three, c='r', marker ='+')
plt.show()

# %%
irisone = df.iloc[0:50,0]
iristwo = df.iloc[50:100,4]
iristhree = df.iloc[100:,4]

# %%
plt.hist(irisone)
# Out:
# (array([ 4.,  1.,  6.,  5., 12.,  8.,  4.,  5.,  2.,  3.]),
#  array([4.3 , 4.45, 4.6 , 4.75, 4.9 , 5.05, 5.2 , 5.35, 5.5 , 5.65, 5.8 ]),
#  <a list of 10 Patch objects>)
